# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import (Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Dropout, Activation, GlobalAveragePooling2D)
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, UpSampling2D
# Load and preprocess MNIST
(x_train, _), (x_test, _) = mnist.load_data()

#data normalization [0,1]
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

#image reshape
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Generate noisy versions
noise_factor_low = 0.1
noise_factor_high = 0.5
x_train_noisy_low = x_train + noise_factor_low * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_train_noisy_high = x_train + noise_factor_high * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy_low = x_test + noise_factor_low * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_test_noisy_high = x_test + noise_factor_high * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

# %%
# Clip pixel values to [0, 1]
x_train_noisy_low = np.clip(x_train_noisy_low, 0., 1.)
x_test_noisy_low = np.clip(x_test_noisy_low, 0., 1.)
x_train_noisy_high = np.clip(x_train_noisy_high, 0., 1.)
x_test_noisy_high = np.clip(x_test_noisy_high, 0., 1.)

# %%
#Visualize in a 3 x 3 grid
n = 3 # number of images to show
plt.figure(figsize=(9, 9))
for i in range(n):
  # Original image
  ax = plt.subplot(n, 3, i * 3 + 1)
  plt.imshow(x_train[i].reshape(28, 28), cmap='gray')
  plt.title("Original")
  plt.axis('off')
  # Low noise image
  ax = plt.subplot(n, 3, i * 3 + 2)
  plt.imshow(x_train_noisy_low[i].reshape(28, 28), cmap='gray')
  plt.title("Noise 0.1")
  plt.axis('off')
  # High noise image
  ax = plt.subplot(n, 3, i * 3 + 3)
  plt.imshow(x_train_noisy_high[i].reshape(28, 28), cmap='gray')
  plt.title("Noise 0.5")
  plt.axis('off')
plt.tight_layout()
plt.show()

# %%
def build_encoder(input_shape=(28, 28, 1)):
  """
  Builds the encoder part of the convolutional autoencoder.
  Parameters:
  input_shape (tuple): Shape of the input image. Default is (28, 28, 1) for MNIST.
  Returns:
  input_img (Keras Input): Input layer of the model.
  encoded (Keras Tensor): Encoded representation after convolution and pooling.
  """
  input_img = Input(shape=input_shape, name="input")
  x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
  x = MaxPooling2D((2, 2), padding='same')(x)
  x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
  encoded = MaxPooling2D((2, 2), padding='same', name="encoded")(x)
  return input_img, encoded

# %%
def build_decoder(encoded_input):
  """
  Builds the decoder part of the convolutional autoencoder.
  Parameters:
  encoded_input (Keras Tensor): The output from the encoder.
  Returns:
  decoded (Keras Tensor): The reconstructed output after upsampling and
  convolution.
  """
  x = Conv2D(64, (3, 3), activation='relu', padding='same')(encoded_input)
  x = UpSampling2D((2, 2))(x)
  x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
  x = UpSampling2D((2, 2))(x)
  decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same', name="decoded")(x)
  return decoded

# %%
def build_autoencoder():
  """
  Constructs and compiles the full convolutional autoencoder by connecting encoder and
  decoder.
  Returns:
  autoencoder (Keras Model): Compiled autoencoder model.
  """
  input_img, encoded_output = build_encoder()
  decoded_output = build_decoder(encoded_output)
  autoencoder = Model(inputs=input_img, outputs=decoded_output, name="autoencoder")
  autoencoder.compile(optimizer=Adam(), loss='binary_crossentropy')
  return autoencoder

# %%
autoencoder = build_autoencoder()
autoencoder.summary()
# Out:
# Model: "autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoded (MaxPooling2D)          │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 7, 7, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 14, 14, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 28, 28, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoded (Conv2D)                │ (None, 28, 28, 1)      │           289 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 74,497 (291.00 KB)
#  Trainable params: 74,497 (291.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Training Autoencoder
# Build the autoencoder from previous steps
autoencoder = build_autoencoder()
# Train with noisy input and clean target
history = autoencoder.fit(
  x_train_noisy_high, x_train,
  epochs=10,
  batch_size=128,
  shuffle=True,
  validation_data=(x_test_noisy_high, x_test)
)
# Out:
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 14ms/step - loss: 0.1560 - val_loss: 0.1117
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.1089 - val_loss: 0.1042
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.1037 - val_loss: 0.1012
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.1012 - val_loss: 0.1009
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0997 - val_loss: 0.0983
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0986 - val_loss: 0.0973
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0978 - val_loss: 0.0966
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0971 - val_loss: 0.0963
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0965 - val_loss: 0.0957
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0960 - val_loss: 0.0956

# %%
# Evaluate the Autoencoder
# Predict the denoised images from noisy test images
denoised_images = autoencoder.predict(x_test_noisy_high)
# Function to display images
def plot_images(noisy_images, denoised_images, clean_images, n=10):
  plt.figure(figsize=(20, 6))
  for i in range(n):
    # Plot noisy images
    plt.subplot(3, n, i + 1)
    plt.imshow(noisy_images[i].reshape(28, 28), cmap='gray')
    plt.title("Noisy Image")
    plt.axis('off')
    # Plot denoised images
    plt.subplot(3, n, i + 1 + n)
    plt.imshow(denoised_images[i].reshape(28, 28), cmap='gray')
    plt.title("Denoised Image")
    plt.axis('off')
    # Plot clean images
    plt.subplot(3, n, i + 1 + 2 * n)
    plt.imshow(clean_images[i].reshape(28, 28), cmap='gray')
    plt.title("Clean Image")
    plt.axis('off')
  plt.show()
# Display the first 10 images
plot_images(x_test_noisy_high, denoised_images, x_test, n=10)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step

# %% [markdown]
# # Exercise: Build a Denoising Convolutional Autoencoder
# Dataset: Devnagiri Handwritten Digital Dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

from PIL import Image

from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
# !unzip '/content/drive/MyDrive/AI and Machine Learning/week4/Copy of devnagari digit.zip' -d '/content/devnagari_digit_extracted'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/10299.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/10300.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/10301.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/10302.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/10303.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/10304.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/10306.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/10307.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104017.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104018.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104019.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104021.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104023.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104024.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104025.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104026.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104027.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104028.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104029.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104030.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104031.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104032.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104033.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104034.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104057.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104058.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104059.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104060.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104061.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104062.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104065.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104066.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104067.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104068.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104069.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104070.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104071.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104072.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104075.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104076.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104078.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104079.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104080.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104082.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104084.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104085.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104086.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104087.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104088.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104089.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104090.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104092.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104094.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104095.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104096.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104098.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104099.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/104101.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12706.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12707.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12709.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12711.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12712.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12713.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12714.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12715.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12716.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12718.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12720.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12721.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12723.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12724.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12725.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12726.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12727.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12728.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12730.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12731.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12732.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12733.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12734.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12735.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12736.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12737.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12738.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/12739.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/13582.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/13583.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/13584.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/13586.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/13587.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/13588.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/13589.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/13590.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/13591.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/13592.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/13593.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/13594.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/13595.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/13596.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/13597.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/13598.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/13600.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/13601.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/22874.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/22875.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/22876.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/22877.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/22878.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/22879.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/22880.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/22881.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/22882.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/22883.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/22884.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/22885.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/22886.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/22887.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/22888.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/22889.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/22890.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30200.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30201.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30202.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30203.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30204.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30205.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30206.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30207.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30208.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30209.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30210.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30211.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30212.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30213.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30214.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30215.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30216.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30217.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30218.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30219.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30220.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30221.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30222.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30223.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30224.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30225.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30226.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30227.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30228.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30229.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30231.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30232.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30233.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30234.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30236.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30237.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/30238.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_7/
png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99730.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99731.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99732.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99733.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99734.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99735.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99736.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99737.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99738.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99739.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99740.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99741.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99742.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99743.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99744.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99745.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99746.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99747.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99748.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99749.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99750.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99753.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99754.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99755.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99756.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99757.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99758.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99759.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99760.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99761.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99762.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99763.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99764.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99766.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99767.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99768.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99769.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99770.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99771.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99773.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99776.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99778.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99779.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99780.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99781.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99783.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99784.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99785.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99787.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99788.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99789.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99790.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99791.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99793.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99795.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99797.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99799.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99800.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99802.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99803.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99804.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99805.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99806.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99808.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99809.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99811.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99812.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99813.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99814.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99815.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99816.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99817.png
#   inflating: /content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset/Train/digit_9/99818.png

# %%
import os

from google.colab import drive
drive.mount('/content/drive')

print(os.listdir('/content/devnagari_digit_extracted'))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['DevanagariHandwrittenDigitDataset']

# %%
print(os.listdir('/content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset'))
# Out:
# ['Train', 'Test']

# %%
data_path = '/content/devnagari_digit_extracted/DevanagariHandwrittenDigitDataset'

train_path = os.path.join(data_path, 'Train')
test_path = os.path.join(data_path, 'Test')

def load_images(folder_path):
    images = []

    for digit in os.listdir(folder_path):
        digit_path = os.path.join(folder_path, digit)

        if os.path.isdir(digit_path):
            for file in os.listdir(digit_path):
                img_path = os.path.join(digit_path, file)

                try:
                    img = Image.open(img_path).convert('L')
                    img = img.resize((28, 28))
                    img = np.array(img)

                    images.append(img)
                except:
                    continue

    return np.array(images)

# %%
x_train = load_images(train_path)
x_test = load_images(test_path)

print("Train shape:", x_train.shape)
print("Test shape:", x_test.shape)
# Out:
# Train shape: (17000, 28, 28)
# Test shape: (3000, 28, 28)

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# %%
noise_factor_low = 0.1
noise_factor_high = 0.5

x_train_noisy_low = x_train + noise_factor_low * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_train_noisy_high = x_train + noise_factor_high * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)

x_test_noisy_low = x_test + noise_factor_low * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)
x_test_noisy_high = x_test + noise_factor_high * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

# Clip
x_train_noisy_low = np.clip(x_train_noisy_low, 0., 1.)
x_train_noisy_high = np.clip(x_train_noisy_high, 0., 1.)

x_test_noisy_low = np.clip(x_test_noisy_low, 0., 1.)
x_test_noisy_high = np.clip(x_test_noisy_high, 0., 1.)

# %%
digit_folders = sorted(os.listdir(train_path))

images_per_digit = {}
for digit in digit_folders:
    digit_path = os.path.join(train_path, digit)
    if os.path.isdir(digit_path):
        images_per_digit[digit] = len([
            f for f in os.listdir(digit_path)
            if os.path.isfile(os.path.join(digit_path, f))
        ])

digit_indices = []
cumulative = 0
for digit in digit_folders:
    if digit in images_per_digit:
        digit_indices.append((digit, cumulative))
        cumulative += images_per_digit[digit]

n_digits = len(digit_indices)
plt.figure(figsize=(20, 6))

for col, (label, idx) in enumerate(digit_indices):
    plt.subplot(3, n_digits, col + 1)
    plt.imshow(x_train[idx].reshape(28, 28), cmap='gray')
    plt.title(f"{label}")
    plt.axis('off')

    plt.subplot(3, n_digits, col + 1 + n_digits)
    plt.imshow(x_train_noisy_low[idx].reshape(28, 28), cmap='gray')
    plt.axis('off')

    plt.subplot(3, n_digits, col + 1 + 2 * n_digits)
    plt.imshow(x_train_noisy_high[idx].reshape(28, 28), cmap='gray')
    plt.axis('off')

# Row labels on the left
plt.gcf().text(0.01, 0.83, "Original", va='center', fontsize=11)
plt.gcf().text(0.01, 0.50, "Noise 0.1", va='center', fontsize=11)
plt.gcf().text(0.01, 0.17, "Noise 0.5", va='center', fontsize=11)

plt.tight_layout()
plt.show()

# %%
def build_encoder(input_shape=(28,28,1)):
    input_img = Input(shape=input_shape, name="input")

    x = Conv2D(32, (3,3), activation='relu', padding='same')(input_img)
    x = MaxPooling2D((2,2), padding='same')(x)

    x = Conv2D(64, (3,3), activation='relu', padding='same')(x)
    encoded = MaxPooling2D((2,2), padding='same', name="encoded")(x)

    return input_img, encoded

# %%
def build_decoder(encoded_input):
    x = Conv2D(64, (3,3), activation='relu', padding='same')(encoded_input)
    x = UpSampling2D((2,2))(x)

    x = Conv2D(32, (3,3), activation='relu', padding='same')(x)
    x = UpSampling2D((2,2))(x)

    decoded = Conv2D(1, (3,3), activation='sigmoid', padding='same', name="decoded")(x)

    return decoded

# %%
def build_autoencoder():
    input_img, encoded_output = build_encoder()
    decoded_output = build_decoder(encoded_output)

    autoencoder = Model(inputs=input_img, outputs=decoded_output)
    autoencoder.compile(optimizer=Adam(), loss='binary_crossentropy')

    return autoencoder

autoencoder = build_autoencoder()
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input (InputLayer)              │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ encoded (MaxPooling2D)          │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 7, 7, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_4 (UpSampling2D)  │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 14, 14, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_5 (UpSampling2D)  │ (None, 28, 28, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ decoded (Conv2D)                │ (None, 28, 28, 1)      │           289 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 74,497 (291.00 KB)
#  Trainable params: 74,497 (291.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = autoencoder.fit(
    x_train_noisy_high, x_train,
    epochs=10,
    batch_size=128,
    shuffle=True,
    validation_data=(x_test_noisy_high, x_test)
)
# Out:
# Epoch 1/10
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 7s 33ms/step - loss: 0.3105 - val_loss: 0.2178
# Epoch 2/10
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2089 - val_loss: 0.2020
# Epoch 3/10
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1998 - val_loss: 0.1967
# Epoch 4/10
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1952 - val_loss: 0.1929
# Epoch 5/10
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1919 - val_loss: 0.1914
# Epoch 6/10
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1899 - val_loss: 0.1886
# Epoch 7/10
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.1881 - val_loss: 0.1882
# Epoch 8/10
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1868 - val_loss: 0.1864
# Epoch 9/10
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1856 - val_loss: 0.1861
# Epoch 10/10
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1849 - val_loss: 0.1850

# %%
denoised_images = autoencoder.predict(x_test_noisy_high)
# Out:
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step

# %%
def plot_images(noisy, denoised, clean, n=10):
    plt.figure(figsize=(20,6))

    for i in range(n):
        plt.subplot(3,n,i+1)
        plt.imshow(noisy[i].reshape(28,28), cmap='gray')
        plt.title("Noisy")
        plt.axis('off')

        plt.subplot(3,n,i+1+n)
        plt.imshow(denoised[i].reshape(28,28), cmap='gray')
        plt.title("Denoised")
        plt.axis('off')

        plt.subplot(3,n,i+1+2*n)
        plt.imshow(clean[i].reshape(28,28), cmap='gray')
        plt.title("Clean")
        plt.axis('off')

    plt.show()

# %%
plot_images(x_test_noisy_high, denoised_images, x_test, n=10)

# %%
plt.figure(figsize=(8,5))

# Training loss
plt.plot(history.history['loss'], label='Training Loss')

# Validation loss
plt.plot(history.history['val_loss'], label='Validation Loss')

plt.title("Training vs Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid()

plt.show()
